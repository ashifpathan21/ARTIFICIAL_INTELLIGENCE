# %%
import pandas as pd 
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score , classification_report

# %%
df = sns.load_dataset("iris")

# %%
X = df.drop("species" , axis=1)
y = df["species"]

# %%
le  = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y_encoded , test_size=0.2 , random_state=42 , stratify=y_encoded)

# %%
meta_learner = KNeighborsClassifier()

# %%
base_learners = [
    ("lr",LogisticRegression(max_iter=1000)),
    ("dt",DecisionTreeClassifier(random_state=42)),
    ("svc",SVC(probability=True , kernel="rbf",random_state=42))
                 ]

# %%
stacking_clf = StackingClassifier(estimators=base_learners,final_estimator=meta_learner , cv=5)

# %%
stacking_clf.fit(X_train , y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('lr', LogisticRegression(max_iter=1000)),
#                                ('dt', DecisionTreeClassifier(random_state=42)),
#                                ('svc', SVC(probability=True, random_state=42))],
#                    final_estimator=KNeighborsClassifier())

# %%
y_pred = stacking_clf.predict(X_test )

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.9666666666666667

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.91      1.00      0.95        10
#            2       1.00      0.90      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(
    n_estimators=100, # no of trees
    max_depth=None,
    random_state=42
    )

# %%
model_rf.fit(X_train , y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model_rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.82      0.90      0.86        10
#            2       0.89      0.80      0.84        10
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %%
from sklearn.ensemble import AdaBoostClassifier , GradientBoostingClassifier

# %%
model_ada = AdaBoostClassifier()

# %%
model_ada.fit(X_train , y_train)
# Out:
# c:\Users\ashif\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier()

# %%
y_pred = model_ada.predict(X_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.9333333333333333

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
model_gr = GradientBoostingClassifier()

# %%
model_gr.fit(X_train , y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = model_gr.predict(X_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.9666666666666667

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.90      0.95        10
#            2       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
from xgboost import XGBClassifier
# Out:
# Requirement already satisfied: xgboost in c:\users\ashif\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\ashif\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\ashif\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %%
model_xgb = XGBClassifier()

# %%
model_xgb.fit(X_train , y_train )
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = model_xgb.predict(X_test)

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.9333333333333333

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
